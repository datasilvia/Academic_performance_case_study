# %%
# Import librerias for EDA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
# Load data
df = pd.read_csv('df_limpito_EDA.csv')

# %%
# Show data
df.head()
# Out:
#    Unnamed: 0  student_id school sex  age address famsize Pstatus  Medu  Fedu  \
# 0           0         1.0     GP   F   18       U     GT3       A     4     4
# 1           1         2.0     GP   F   17       U     GT3       T     1     1
# 2           2         3.0     GP   F   15       U     LE3       T     1     1
# 3           3         4.0     GP   F   15       U     GT3       T     4     2
# 4           4         5.0     GP   F   16       U     GT3       T     3     3
#
#    ... internet romantic  famrel  freetime  Dalc Walc absences_por por_score  \
# 0  ...       no       no       4         3     1    1          4.0      11.0
# 1  ...      yes       no       5         3     1    1          2.0      11.0
# 2  ...      yes       no       4         3     2    3          6.0      12.0
# 3  ...      yes      yes       3         2     1    1          0.0      14.0
# 4  ...       no       no       4         3     1    2          0.0      13.0
#
#   absences_math math_score
# ...

# %%
# Show data types
df.dtypes
# Out:
# Unnamed: 0         int64
# student_id       float64
# school            object
# sex               object
# age                int64
# address           object
# famsize           object
# Pstatus           object
# Medu               int64
# Fedu               int64
# Mjob              object
# Fjob              object
# traveltime         int64
# studytime          int64
# failures           int64
# schoolsup         object
# famsup            object
# paid              object
# activities        object
# nursery           object
# internet          object
# romantic          object
# famrel             int64
# freetime           int64
# Dalc               int64
# Walc               int64
# absences_por     float64
# por_score        float64
# absences_math    float64
# math_score       float64
# dtype: object

# %%
# Crear nuevas columnas 'por_status' y 'math_status' basadas en 'por_score' y 'math_score'
df['por_status'] = df['por_score'].apply(lambda x: 'aprobado' if x >= 10 else 'suspenso')
df['math_status'] = df['math_score'].apply(lambda x: 'aprobado' if x >= 10 else 'suspenso')

# Mostrar las primeras filas para verificar
df[['por_score', 'por_status', 'math_score', 'math_status']].head()
# Out:
#    por_score por_status  math_score math_status
# 0       11.0   aprobado         6.0    suspenso
# 1       11.0   aprobado         6.0    suspenso
# 2       12.0   aprobado         NaN    suspenso
# 3       14.0   aprobado         NaN    suspenso
# 4       13.0   aprobado         NaN    suspenso

# %%
# Info data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 882 entries, 0 to 881
# Data columns (total 32 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     882 non-null    int64
#  1   student_id     882 non-null    float64
#  2   school         882 non-null    object
#  3   sex            882 non-null    object
#  4   age            882 non-null    int64
#  5   address        882 non-null    object
#  6   famsize        882 non-null    object
#  7   Pstatus        882 non-null    object
#  8   Medu           882 non-null    int64
#  9   Fedu           882 non-null    int64
#  10  Mjob           882 non-null    object
#  11  Fjob           882 non-null    object
#  12  traveltime     882 non-null    int64
#  13  studytime      882 non-null    int64
#  14  failures       882 non-null    int64
#  15  schoolsup      882 non-null    object
#  16  famsup         882 non-null    object
# ...

# %%
# Describe data
df.describe()
# Out:
#        Unnamed: 0   student_id         age        Medu        Fedu  \
# count  882.000000   882.000000  882.000000  882.000000  882.000000
# mean   440.500000   465.731293   16.772109    2.573696    2.349206
# std    254.755765   290.378577    1.243915    1.131386    1.091940
# min      0.000000     1.000000   15.000000    0.000000    0.000000
# 25%    220.250000   221.250000   16.000000    2.000000    1.000000
# 50%    440.500000   441.500000   17.000000    3.000000    2.000000
# 75%    660.750000   672.750000   18.000000    4.000000    3.000000
# max    881.000000  1044.000000   22.000000    4.000000    4.000000
#
#        traveltime   studytime    failures      famrel    freetime        Dalc  \
# count  882.000000  882.000000  882.000000  882.000000  882.000000  882.000000
# mean     1.530612    1.967120    0.289116    3.925170    3.184807    1.505669
# std      0.730147    0.832134    0.681585    0.934313    1.048688    0.914303
# ...

# %%
# Check missing values
df.isnull().sum()
# Out:
# Unnamed: 0         0
# student_id         0
# school             0
# sex                0
# age                0
# address            0
# famsize            0
# Pstatus            0
# Medu               0
# Fedu               0
# Mjob               0
# Fjob               0
# traveltime         0
# studytime          0
# failures           0
# schoolsup          0
# famsup             0
# paid               0
# activities         0
# nursery            0
# internet           0
# romantic           0
# famrel             0
# freetime           0
# Dalc               0
# Walc               0
# absences_por     233
# por_score        233
# absences_math    487
# math_score       487
# por_status         0
# math_status        0
# dtype: int64

# %%
# Establecer el estilo de Seaborn
sns.set_style('darkgrid')

# Distribución de variables numéricas
df.hist(bins=30, figsize=(20, 15), color='skyblue', edgecolor='black')
plt.suptitle('Distribution of Numerical Variables', fontsize=20)
plt.show()

# %%
# 1. Age Distribution

plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='age', palette='viridis')
plt.title('Bar Plot of Age Distribution', fontsize=18)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
sns.despine()
plt.show()

# %%
# 2.Gender Distribution 

plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='sex', palette='viridis')
plt.title('Distribution of Gender', fontsize=18, fontweight='bold')
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
sns.despine()
plt.show()

# %%
# Contar la cantidad de cada género
gender_counts = df['sex'].value_counts()

# Crear el gráfico de pastel
plt.figure(figsize=(8, 8))
colors = sns.color_palette('viridis', len(gender_counts))
explode = (0.05, 0.05)  # Separación entre las porciones

plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140, colors=colors, explode=explode, shadow=True, wedgeprops={'edgecolor': 'black'})
plt.title('Distribution of Gender', fontsize=18, fontweight='bold')
plt.axis('equal')  # Para asegurar que el gráfico sea un círculo
plt.show()

# %%
# 3.Study time by Gender

plt.figure(figsize=(10, 5))
sns.histplot(data=df, x='studytime', hue='sex', kde=True, palette='viridis', multiple='stack')
plt.title('Distribution of Study Time by Gender', fontsize=15)
plt.xlabel('Study Time')
plt.ylabel('Frequency')
plt.show()

# %%
# 3. Age Distribution by Gender

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='sex', y='age', palette='Set2')
plt.title('Age Distribution by Gender', fontsize=18, fontweight='bold')
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Age', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
sns.despine()
plt.show()

# %%
# 4. Distribution of Portuguese Scores

plt.figure(figsize=(12, 6))
sns.histplot(df['por_score'].dropna(), kde=True, color='blue', edgecolor='black', bins=30)
plt.title('Distribution of Portuguese Scores', fontsize=18, fontweight='bold')
plt.xlabel('Portuguese Score', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
sns.despine()
plt.show()

# %%
# 5. Distribution of math Scores

plt.figure(figsize=(12, 6))
sns.histplot(df['math_score'].dropna(), kde=True, color='blue', edgecolor='black', bins=30)
plt.title('Distribution of math Scores', fontsize=18, fontweight='bold')
plt.xlabel('math Score', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
sns.despine()
plt.show()

# %%
# 6.Distribution of Portuguese and Math Scores

plt.figure(figsize=(12, 6))
sns.histplot(df['por_score'].dropna(), kde=True, color='blue', edgecolor='black', bins=30, label='Portuguese Score', alpha=0.6)
sns.histplot(df['math_score'].dropna(), kde=True, color='green', edgecolor='black', bins=30, label='Math Score', alpha=0.6)
plt.title('Distribution of Portuguese and Math Scores', fontsize=18, fontweight='bold')
plt.xlabel('Score', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
sns.despine()
plt.show()

# %%
# 7. Distribution of Portuguese Scores by Gender

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='sex', y='por_score', palette='pastel')
plt.title('Portuguese Scores by Gender', fontsize=18, fontweight='bold')
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Portuguese Score', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
sns.despine()
plt.show()

# %%
# 8. Distribution Math Scores by Gender

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='sex', y='math_score', palette='Set3')
plt.title('Math Scores by Gender', fontsize=18, fontweight='bold')
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Math Score', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
sns.despine()
plt.show()

# %%
# 9.Countplot of Travel Time by Gender

plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='traveltime', hue='sex', palette='viridis')
plt.title('Countplot of Travel Time by Gender', fontsize=18, fontweight='bold')
plt.xlabel('Travel Time', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
sns.despine()
plt.show()

# %%
# 10.Countplot of Free Time by Gender

plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='freetime', hue='sex', palette='pastel')
plt.title('Countplot of Free Time by Gender', fontsize=18, fontweight='bold')
plt.xlabel('Free Time', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
sns.despine()
plt.show()

# %%
# 11.Portuguese Scores by Study Time and Gender

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='studytime', y='por_score', hue='sex', palette='Set1')
plt.title('Portuguese Scores by Study Time and Gender', fontsize=18, fontweight='bold')
plt.xlabel('Study Time', fontsize=14)
plt.ylabel('Portuguese Score', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
sns.despine()
plt.show()

# %%
# 12.Math Scores by Study Time and Gender

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='studytime', y='math_score', hue='sex', palette='Set1')
plt.title('Math Scores by Study Time and Gender', fontsize=18, fontweight='bold')
plt.xlabel('Study Time', fontsize=14)
plt.ylabel('Math Score', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
sns.despine()
plt.show()

# %%
#13. Distribution of Mother's Job

plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Mjob', palette='viridis')
plt.title('Distribution of Mother\'s Job', fontsize=15)
plt.xticks(rotation=45)
plt.show()

# %%
#14. Distribution of Father's Job

plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='Fjob', palette='viridis')
plt.title('Distribution of Father\'s Job', fontsize=15)
plt.xticks(rotation=45)
plt.show()

# %%
#15. Portuguese Scores by Mother's Job

plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Mjob', y='por_score', palette='Set2')
plt.title('Portuguese Scores by Mother\'s Job', fontsize=15)
plt.xticks(rotation=45)
plt.show()

# %%
# 16. Math Scores by Mother's Job

plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Mjob', y='math_score', palette='Set2')
plt.title('Math Scores by Mother\'s Job', fontsize=15)
plt.xticks(rotation=45)
plt.show()

# %%
# 17. Portuguese Scores by Father's Job

plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Fjob', y='por_score', palette='Set2')
plt.title('Portuguese Scores by Father\'s Job', fontsize=15)
plt.xticks(rotation=45)
plt.show()

# %%
# 18. Math Scores by Father's Job

plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x='Fjob', y='math_score', palette='Set2')
plt.title('Math Scores by Father\'s Job', fontsize=15)
plt.xticks(rotation=45)
plt.show()

# %%
# 19. Distribution of Guardian

plt.figure(figsize=(10, 5))
sns.countplot(data=df, x='romantic', palette='coolwarm')
plt.title('Distribution of Romantic Status', fontsize=15)
plt.show()

# %%
# 20. Portuguese Scores vs Math Scores by Romantic Status

plt.figure(figsize=(10, 5))
sns.scatterplot(data=df, x='por_score', y='math_score', hue='romantic', palette='coolwarm')
plt.title('Portuguese Scores vs Math Scores by Romantic Status', fontsize=15)
plt.show()

# %%
# Analysis of the dataset

# Distribution of mother's job
mjob_distribution = df['Mjob'].value_counts(normalize=True) * 100

# Distribution of father's job
fjob_distribution = df['Fjob'].value_counts(normalize=True) * 100

# Distribution of romantic status
romantic_distribution = df['romantic'].value_counts(normalize=True) * 100

# Average scores in Portuguese and Math by gender
avg_scores_by_gender = df.groupby('sex')[['por_score', 'math_score']].mean()

# Average scores in Portuguese and Math by romantic status
avg_scores_by_romantic = df.groupby('romantic')[['por_score', 'math_score']].mean()

# Average scores in Portuguese and Math by mother's job
avg_scores_by_mjob = df.groupby('Mjob')[['por_score', 'math_score']].mean()

# Average scores in Portuguese and Math by father's job
avg_scores_by_fjob = df.groupby('Fjob')[['por_score', 'math_score']].mean()

# Distribution of absences in Portuguese
absences_por_distribution = df['absences_por'].describe()

# Distribution of absences in Math
absences_math_distribution = df['absences_math'].describe()

# Distribution of travel time
traveltime_distribution = df['traveltime'].describe()

# Distribution of free time
freetime_distribution = df['freetime'].describe()

# Generate the analysis in Markdown format
markdown_analysis = f"""
# Statistical Analysis of the Dataset

## Distribution of Mother's Job
{mjob_distribution.to_markdown()}

## Distribution of Father's Job
{fjob_distribution.to_markdown()}

## Distribution of Romantic Status
{romantic_distribution.to_markdown()}

## Average Scores in Portuguese and Math by Gender
{avg_scores_by_gender.to_markdown()}

## Average Scores in Portuguese and Math by Romantic Status
{avg_scores_by_romantic.to_markdown()}

## Average Scores in Portuguese and Math by Mother's Job
{avg_scores_by_mjob.to_markdown()}

## Average Scores in Portuguese and Math by Father's Job
{avg_scores_by_fjob.to_markdown()}

## Distribution of Absences in Portuguese
{absences_por_distribution.to_markdown()}

## Distribution of Absences in Math
{absences_math_distribution.to_markdown()}

## Distribution of Travel Time
{traveltime_distribution.to_markdown()}

## Distribution of Free Time
{freetime_distribution.to_markdown()}
"""

# Save the analysis to a Markdown file
with open('analysis.md', 'w') as f:
    f.write(markdown_analysis)

print("Analysis saved to 'analysis.md'")
# Out:
# Analysis saved to 'analysis.md'
